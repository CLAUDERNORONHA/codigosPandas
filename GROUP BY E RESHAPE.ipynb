# %%
import pandas as pd
import numpy as np

# %%
drinks = pd.read_csv('drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent
# 0                           0.0  34.660.000      Asia
# 1                           4.9   2.876.000    Europe
# 2                           0.7  40.061.000    Africa
# 3                          12.4  77.281.000    Europe
# 4                           5.9  28.081.000    Africa

# %% [markdown]
# UTILIZANDO O APPLY PARA APLICAR FUNÇOES EM DATAFRAME

# %%
def consumo(a):
    if a <= 75:
        return 'baixo'
    elif a >= 75:
        return 'Alto'
    else:
        return 'Moderado'

# %%
# cria uma coluna no Dataframe para saber o nivel de consumo de alcool
drinks['consumo'] = drinks['beer_servings'].apply(consumo)

# %%
drinks.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# ...

# %% [markdown]
# EXPORTANDO DATAFRAMES

# %%
# sem indexação
drinks.to_csv('drinks_consumo.csv', encoding='utf-8', index=False)

# %%
# com indexação
drinks.to_csv('drinks_indice.csv', encoding='utf-8', index=True)

# %%
# Alterando o separador e indexação padrao
drinks.to_csv('drinks_default.csv', encoding='utf8', sep='\t')

# %% [markdown]
# IMPORTANDO

# %%
# dataframe que temos trabalhar - index

# %%
drinks = pd.read_csv('drinks_consumo.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent consumo
# 0                           0.0  34.660.000      Asia   baixo
# 1                           4.9   2.876.000    Europe    Alto
# 2                           0.7  40.061.000    Africa   baixo
# 3                          12.4  77.281.000    Europe    Alto
# 4                           5.9  28.081.000    Africa    Alto

# %%
drinks = pd.read_csv('drinks_indice.csv')

# %%
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent consumo
# 0                           0.0  34.660.000      Asia   baixo
# 1                           4.9   2.876.000    Europe    Alto
# 2                           0.7  40.061.000    Africa   baixo
# 3                          12.4  77.281.000    Europe    Alto
# 4                           5.9  28.081.000    Africa    Alto

# %% [markdown]
# APAGANDO UMA COLUNA

# %%
del drinks['population']

# %%
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent consumo
# 0                           0.0      Asia   baixo
# 1                           4.9    Europe    Alto
# 2                           0.7    Africa   baixo
# 3                          12.4    Europe    Alto
# 4                           5.9    Africa    Alto

# %%
# aplicando groupby

# %%
drinks_1 = drinks.groupby('continent')

# %%
type(drinks_1)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
drinks_1.groups
# Out:
# {'Africa': Int64Index([  2,   4,  18,  22,  26,  27,  28,  29,  31,  33,  34,  38,  39,
#               47,  49,  53,  55,  56,  58,  62,  63,  66,  70,  71,  88,  95,
#               96,  97, 100, 101, 104, 107, 108, 114, 115, 117, 123, 124, 142,
#              148, 150, 152, 153, 158, 159, 162, 164, 172, 175, 179, 183, 191,
#              192],
#             dtype='int64'),
#  'Asia': Int64Index([  0,  12,  13,  19,  24,  30,  36,  46,  77,  78,  79,  80,  82,
#               85,  86,  87,  90,  91,  92,  94, 102, 103, 112, 116, 119, 127,
#              128, 134, 137, 138, 141, 149, 154, 161, 167, 168, 169, 171, 176,
#              177, 181, 186, 189, 190],
#             dtype='int64'),
#  'Europe': Int64Index([  1,   3,   7,   9,  10,  15,  16,  21,  25,  42,  44,  45,  48,
#               57,  60,  61,  64,  65,  67,  75,  76,  81,  83,  93,  98,  99,
#              105, 111, 113, 120, 126, 135, 136, 139, 140, 147, 151, 155, 156,
#              160, 165, 166, 170, 180, 182],
# ...

# %%
len(drinks_1.groups)
# Out:
# 6

# %%
ordenaDrinks = drinks_1.size()

# %%
ordenaDrinks
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# dtype: int64

# %%
# ORDENAR OS GRUPOS POR ORDEM CRESCENTE

# %%
ordenaDrinks.sort_values(ascending = True)
# Out:
# continent
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# dtype: int64

# %% [markdown]
# AGRUPAR POR MAIS COLUNAS

# %%
drinks_2 = drinks.groupby(['continent','consumo'])

# %%
total = drinks_2.size()
total.sort_values(ascending = False)
total
# Out:
# continent      consumo
# Africa         Alto       14
#                baixo      39
# Asia           Alto        8
#                baixo      36
# Europe         Alto       39
#                baixo       6
# North America  Alto       18
#                baixo       5
# Oceania        Alto        6
#                baixo      10
# South America  Alto       12
# dtype: int64

# %%
drinks.head(10)
# Out:
#    Unnamed: 0            country  beer_servings  spirit_servings  \
# 0           0        Afghanistan              0                0
# 1           1            Albania             89              132
# 2           2            Algeria             25                0
# 3           3            Andorra            245              138
# 4           4             Angola            217               57
# 5           5  Antigua & Barbuda            102              128
# 6           6          Argentina            193               25
# 7           7            Armenia             21              179
# 8           8          Australia            261               72
# 9           9            Austria            279               75
#
#    wine_servings  total_litres_of_pure_alcohol      continent consumo
# 0              0                           0.0           Asia   baixo
# 1             54                           4.9         Europe    Alto
# ...
